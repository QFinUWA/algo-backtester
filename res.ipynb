# %%
import pandas as pd
aapl = pd.read_csv(r"C:\Users\isaac\Downloads\data\AAPL.csv")

# %%
df = pd.read_csv('results.csv')


# goog = pd.read_csv(r"C:\Users\isaac\Downloads\data\GOOG.csv")

# %%
df['AAPL'] = aapl['close']
# df['GOOG'] = goog['close']
A = df['AAPL_long'] + df['AAPL_cover'] - df['AAPL_sell'] - df['AAPL_short']

# G = -df['GOOG_long'] - df['GOOG_cover'] + df['GOOG_sell'] + df['GOOG_short']


df['HOLDINGS'] = A.cumsum()*df['AAPL'] 
df['DEPOSIT'] = (df['AAPL_short']*df['AAPL']).cumsum()
df['VALUE'] = 0.999*(df['HOLDINGS'] + df['DEPOSIT'])  + df['DEPOSIT'] + df['balance']

# %%
df
# Out:
#                            Unnamed: 0     balance  AAPL_long  AAPL_sell  \
# 0       1970-01-01 00:00:00.000000000  727.599800        0.0        0.0
# 1       1970-01-01 00:00:00.000000001  455.083426        0.0        0.0
# 2       1970-01-01 00:00:00.000000002  182.576930        0.0        0.0
# 3       1970-01-01 00:00:00.000000003  182.576930        0.0        0.0
# 4       1970-01-01 00:00:00.000000004  182.576930        0.0        0.0
# ...                               ...         ...        ...        ...
# 682565  1970-01-01 00:00:00.000682565  182.576930        0.0        0.0
# 682566  1970-01-01 00:00:00.000682566  182.576930        0.0        0.0
# 682567  1970-01-01 00:00:00.000682567  182.576930        0.0        0.0
# 682568  1970-01-01 00:00:00.000682568  182.576930        0.0        0.0
# 682569  1970-01-01 00:00:00.000682569  182.576930        0.0        0.0
#
#         AAPL_short  AAPL_cover        AAPL    HOLDINGS     DEPOSIT  \
# 0              2.0         0.0  136.127789 -272.255578  272.255578
# 1              2.0         0.0  136.112492 -544.449969  544.480563
# 2              2.0         0.0  136.131934 -816.791604  816.744431
# 3              0.0         0.0  136.112196 -816.673177  816.744431
# 4              0.0         0.0  136.082589 -816.495537  816.744431
# ...            ...         ...         ...         ...         ...
# 682565         0.0         0.0  124.510000 -747.060000  816.744431
# 682566         0.0         0.0  124.640000 -747.840000  816.744431
# 682567         0.0         0.0  124.600000 -747.600000  816.744431
# 682568         0.0         0.0  124.630000 -747.780000  816.744431
# 682569         0.0         0.0  124.660000 -747.960000  816.744431
#
#               VALUE
# 0        999.855378
# 1        999.594582
# 2        999.274188
# 3        999.392615
# 4        999.570255
# ...             ...
# 682565  1069.005792
# 682566  1068.225792
# 682567  1068.465792
# 682568  1068.285792
# 682569  1068.105792
#
# [682570 rows x 10 columns]

# %%
df.to_csv('results_test.csv')

# %%
df['AAPL_D'] = 1000*df['AAPL']/df['AAPL'][0]
# df['GOOG_D'] = 1000*df['GOOG']/df['GOOG'][0]
df.plot( y=['VALUE', 'AAPL_D'])
# Out:
# <AxesSubplot:>
